# %%
import os

# %% [markdown]
# To activate use
# .\tflow\Scripts\activate
#
# and
# ipykernel kernel name is tflowj
#
# (No need to use this just for understanding)
# python -m ipykernel install --user --name=tflowj
#
# (We need to create virtual environment only once when we start the project)
# python -m venv tflow

# %% [markdown]
# Initializing Paths and Models

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_fpnlite_640_5'
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME),
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'),
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'),
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'),
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME),
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 86847, done.
# remote: Counting objects: 100% (601/601), done.
# remote: Compressing objects: 100% (294/294), done.
# remote: Total 86847 (delta 332), reused 551 (delta 300), pack-reused 86246
# Receiving objects: 100% (86847/86847), 598.95 MiB | 24.21 MiB/s, done.
# Resolving deltas: 100% (62214/62214), done.

# %%
if os.name=='posix':
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .

if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# protobuf-compiler is already the newest version (3.12.4-1ubuntu7.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 9 not upgraded.
# Processing /content/Tensorflow/models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3 (from object-detection==0.1)
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam (from object-detection==0.1)
#   Downloading apache_beam-2.49.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (9.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (4.9.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (0.29.36)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (21.6.0)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.0.6)
# Collecting lvis (from object-detection==0.1)
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (1.5.3)
# Collecting tf-models-official>=2.5.1 (from object-detection==0.1)
#   Downloading tf_models_official-2.13.1-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 73.6 MB/s eta 0:00:00
# Collecting tensorflow_io (from object-detection==0.1)
#   Downloading tensorflow_io-0.32.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (28.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.0/28.0 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from object-detection==0.1) (2.12.0)
# Collecting pyparsing==2.4.7 (from object-detection==0.1)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.9 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0 (from object-detection==0.1)
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 13.4 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.22.4)
# Collecting colorama (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.84.0)
# Collecting immutabledict (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading immutabledict-3.0.0-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.16)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.0.74)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Collecting pyyaml<5.4.0,>=5.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 28.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.7 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.9.2)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.14.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 30.7 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.13.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_text-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 72.0 MB/s eta 0:00:00
# Collecting tensorflow~=2.13.0 (from tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->object-detection==0.1) (2022.7.1)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Collecting crcmod<2.0,>=1.7 (from apache-beam->object-detection==0.1)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting orjson<4.0 (from apache-beam->object-detection==0.1)
#   Downloading orjson-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 17.0 MB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache-beam->object-detection==0.1)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Collecting fastavro<2,>=0.23.6 (from apache-beam->object-detection==0.1)
#   Downloading fastavro-1.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 94.4 MB/s eta 0:00:00
# Collecting fasteners<1.0,>=0.3 (from apache-beam->object-detection==0.1)
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.56.2)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache-beam->object-detection==0.1)
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Collecting objsize<0.7.0,>=0.6.1 (from apache-beam->object-detection==0.1)
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache-beam->object-detection==0.1)
#   Downloading pymongo-4.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (603 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.6/603.6 kB 56.5 MB/s eta 0:00:00
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.22.3)
# Requirement already satisfied: protobuf<4.24.0,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (4.7.1)
# Collecting zstandard<1,>=0.18.0 (from apache-beam->object-detection==0.1)
#   Downloading zstandard-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 86.4 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow<12.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (4.41.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->object-detection==0.1) (23.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2023.7.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.16)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.0.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache-beam->object-detection==0.1)
#   Downloading dnspython-2.4.1-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.3/300.3 kB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Collecting keras (from object-detection==0.1)
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 87.5 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (67.7.2)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 72.5 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1)
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 48.3 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.0)
# Collecting typing-extensions>=3.7.0 (from apache-beam->object-detection==0.1)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Collecting numpy>=1.17 (from sacrebleu<=2.2.0->object-detection==0.1)
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 58.3 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.6)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.4.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.13.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.41.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (6.0.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.16.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.59.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.3.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow~=2.13.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, crcmod, dill, pyyaml, seqeval, docopt
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697172 sha256=2e6719b7e99840d34156b75d5789f7aac7d3eb691e1a151b570a8ac8bfb1ba35
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tsljl7k5/wheels/fb/c9/43/709f88e66b36649c7a29812ca4f6236f31caed949aabc3e335
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=43991 sha256=40c66c42ae7ba673e41113679169134b33f402b500dcfd06c971aa5faaba564d
#   Stored in directory: /root/.cache/pip/wheels/bc/85/62/6cdd81c56f923946b401cecff38055b94c9b766927f7d8ca82
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31404 sha256=1d40c62f5c2103d1e7da7be42e10fdc410fda76abb0afee844056f87a28ede40
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78543 sha256=d88657101e5cef6f2de3142728db5a9fa8d1b7a8f564c6f7546eb0a7c5d9ffb8
#   Stored in directory: /root/.cache/pip/wheels/ea/e2/86/64980d90e297e7bf2ce588c2b96e818f5399c515c4bb8a7e4f
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp310-cp310-linux_x86_64.whl size=44635 sha256=3c95ed150a376712873130773d4a1cf5adaebd33e9ccdc3bee3b79df14607938
#   Stored in directory: /root/.cache/pip/wheels/0b/a9/6a/d0a6981a8dbb698845178818642f72ce179f14336908c7df01
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16165 sha256=3c2c46d6d4805e1f7c15d77bf6abc9cfa7a7e49f318cc48ba3cdc8e6dd24d277
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=c043c08f78c524a29f38fea996501ce17c5fad4f40ac818c4da8915ab3a720d1
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built object-detection avro-python3 crcmod dill pyyaml seqeval docopt
# Installing collected packages: sentencepiece, docopt, crcmod, zstandard, typing-extensions, tensorflow_io, tensorflow-estimator, pyyaml, pyparsing, portalocker, orjson, objsize, numpy, keras, immutabledict, fasteners, fastavro, dnspython, dill, colorama, avro-python3, tensorflow-model-optimization, sacrebleu, pymongo, hdfs, apache-beam, tensorboard, seqeval, lvis, tensorflow, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.3
#     Uninstalling tensorboard-2.12.3:
#       Successfully uninstalled tensorboard-2.12.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flax 0.7.0 requires PyYAML>=5.4.1, but you have pyyaml 5.3.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.3 which is incompatible.
# Successfully installed apache-beam-2.49.0 avro-python3-1.10.2 colorama-0.4.6 crcmod-1.7 dill-0.3.1.1 dnspython-2.4.1 docopt-0.6.2 fastavro-1.8.2 fasteners-0.18 hdfs-2.7.0 immutabledict-3.0.0 keras-2.13.1 lvis-0.5.3 numpy-1.24.3 object-detection-0.1 objsize-0.6.1 orjson-3.9.2 portalocker-2.7.0 pymongo-4.4.1 pyparsing-2.4.7 pyyaml-5.3.1 sacrebleu-2.2.0 sentencepiece-0.1.99 seqeval-1.2.2 tensorboard-2.13.0 tensorflow-2.13.0 tensorflow-estimator-2.13.0 tensorflow-model-optimization-0.7.5 tensorflow-text-2.13.0 tensorflow_io-0.32.0 tf-models-official-2.13.1 typing-extensions-4.5.0 zstandard-0.21.0

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2023-07-31 02:46:28.036644: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-31 02:46:29.465376: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-07-31 02:46:32.878125: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:33.463021: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:33.463333: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Running tests under Python 3.10.6: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-07-31 02:46:33.477488: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:33.477749: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:33.477950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:34.524796: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:34.525118: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:34.525323: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 02:46:34.525488: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-07-31 02:46:34.525544: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13692 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0731 02:46:34.551269 134708137824896 batch_normalization.py:1531] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0731 02:46:35.138952 134708137824896 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.17s
# I0731 02:46:35.636707 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.17s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 2.03s
# I0731 02:46:37.671007 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 2.03s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 1.2s
# I0731 02:46:38.868241 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 1.2s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 1.41s
# I0731 02:46:40.280464 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 1.41s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 7.51s
# I0731 02:46:47.792037 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 7.51s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0731 02:46:47.801779 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.06s
# I0731 02:46:47.858445 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.06s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.04s
# I0731 02:46:47.898805 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.04s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.03s
# I0731 02:46:47.929744 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.19s
# I0731 02:46:48.118498 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.19s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.18s
# I0731 02:46:48.298131 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.18s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.3s
# I0731 02:46:48.601265 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.3s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.34s
# I0731 02:46:48.952596 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.34s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.33s
# I0731 02:46:49.281627 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.33s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.07s
# I0731 02:46:49.348214 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.07s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0731 02:46:49.776677 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0731 02:46:49.776878 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0731 02:46:49.776962 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I0731 02:46:49.781036 134708137824896 efficientnet_model.py:143] round_filter input=32 output=32
# I0731 02:46:49.823461 134708137824896 efficientnet_model.py:143] round_filter input=32 output=32
# I0731 02:46:49.823591 134708137824896 efficientnet_model.py:143] round_filter input=16 output=16
# I0731 02:46:49.953936 134708137824896 efficientnet_model.py:143] round_filter input=16 output=16
# I0731 02:46:49.954130 134708137824896 efficientnet_model.py:143] round_filter input=24 output=24
# I0731 02:46:50.284729 134708137824896 efficientnet_model.py:143] round_filter input=24 output=24
# I0731 02:46:50.284922 134708137824896 efficientnet_model.py:143] round_filter input=40 output=40
# I0731 02:46:50.601137 134708137824896 efficientnet_model.py:143] round_filter input=40 output=40
# I0731 02:46:50.601342 134708137824896 efficientnet_model.py:143] round_filter input=80 output=80
# I0731 02:46:51.264159 134708137824896 efficientnet_model.py:143] round_filter input=80 output=80
# I0731 02:46:51.264364 134708137824896 efficientnet_model.py:143] round_filter input=112 output=112
# I0731 02:46:52.010919 134708137824896 efficientnet_model.py:143] round_filter input=112 output=112
# I0731 02:46:52.011126 134708137824896 efficientnet_model.py:143] round_filter input=192 output=192
# I0731 02:46:52.973862 134708137824896 efficientnet_model.py:143] round_filter input=192 output=192
# I0731 02:46:52.974073 134708137824896 efficientnet_model.py:143] round_filter input=320 output=320
# I0731 02:46:53.210537 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0731 02:46:53.299468 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 02:46:53.421200 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0731 02:46:53.421419 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I0731 02:46:53.421527 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 4
# I0731 02:46:53.424733 134708137824896 efficientnet_model.py:143] round_filter input=32 output=32
# I0731 02:46:53.453474 134708137824896 efficientnet_model.py:143] round_filter input=32 output=32
# I0731 02:46:53.453603 134708137824896 efficientnet_model.py:143] round_filter input=16 output=16
# I0731 02:46:53.766961 134708137824896 efficientnet_model.py:143] round_filter input=16 output=16
# I0731 02:46:53.767210 134708137824896 efficientnet_model.py:143] round_filter input=24 output=24
# I0731 02:46:54.604408 134708137824896 efficientnet_model.py:143] round_filter input=24 output=24
# I0731 02:46:54.604623 134708137824896 efficientnet_model.py:143] round_filter input=40 output=40
# I0731 02:46:55.421826 134708137824896 efficientnet_model.py:143] round_filter input=40 output=40
# I0731 02:46:55.422036 134708137824896 efficientnet_model.py:143] round_filter input=80 output=80
# I0731 02:46:56.069022 134708137824896 efficientnet_model.py:143] round_filter input=80 output=80
# I0731 02:46:56.069230 134708137824896 efficientnet_model.py:143] round_filter input=112 output=112
# I0731 02:46:57.006064 134708137824896 efficientnet_model.py:143] round_filter input=112 output=112
# I0731 02:46:57.006271 134708137824896 efficientnet_model.py:143] round_filter input=192 output=192
# I0731 02:46:58.831253 134708137824896 efficientnet_model.py:143] round_filter input=192 output=192
# I0731 02:46:58.831460 134708137824896 efficientnet_model.py:143] round_filter input=320 output=320
# I0731 02:46:59.110768 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0731 02:46:59.158338 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 02:46:59.266992 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0731 02:46:59.267157 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 112
# I0731 02:46:59.267230 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 5
# I0731 02:46:59.270098 134708137824896 efficientnet_model.py:143] round_filter input=32 output=32
# I0731 02:46:59.295080 134708137824896 efficientnet_model.py:143] round_filter input=32 output=32
# I0731 02:46:59.295211 134708137824896 efficientnet_model.py:143] round_filter input=16 output=16
# I0731 02:46:59.508010 134708137824896 efficientnet_model.py:143] round_filter input=16 output=16
# I0731 02:46:59.508202 134708137824896 efficientnet_model.py:143] round_filter input=24 output=24
# I0731 02:46:59.915668 134708137824896 efficientnet_model.py:143] round_filter input=24 output=24
# I0731 02:46:59.915841 134708137824896 efficientnet_model.py:143] round_filter input=40 output=48
# I0731 02:47:00.347770 134708137824896 efficientnet_model.py:143] round_filter input=40 output=48
# I0731 02:47:00.347962 134708137824896 efficientnet_model.py:143] round_filter input=80 output=88
# I0731 02:47:00.926224 134708137824896 efficientnet_model.py:143] round_filter input=80 output=88
# I0731 02:47:00.926435 134708137824896 efficientnet_model.py:143] round_filter input=112 output=120
# I0731 02:47:01.501068 134708137824896 efficientnet_model.py:143] round_filter input=112 output=120
# I0731 02:47:01.501285 134708137824896 efficientnet_model.py:143] round_filter input=192 output=208
# I0731 02:47:02.232951 134708137824896 efficientnet_model.py:143] round_filter input=192 output=208
# I0731 02:47:02.233159 134708137824896 efficientnet_model.py:143] round_filter input=320 output=352
# I0731 02:47:02.527647 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=1408
# I0731 02:47:02.589361 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 02:47:02.697911 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0731 02:47:02.698083 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I0731 02:47:02.698173 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I0731 02:47:02.701164 134708137824896 efficientnet_model.py:143] round_filter input=32 output=40
# I0731 02:47:02.732073 134708137824896 efficientnet_model.py:143] round_filter input=32 output=40
# I0731 02:47:02.732200 134708137824896 efficientnet_model.py:143] round_filter input=16 output=24
# I0731 02:47:02.979029 134708137824896 efficientnet_model.py:143] round_filter input=16 output=24
# I0731 02:47:02.979214 134708137824896 efficientnet_model.py:143] round_filter input=24 output=32
# I0731 02:47:03.405887 134708137824896 efficientnet_model.py:143] round_filter input=24 output=32
# I0731 02:47:03.406095 134708137824896 efficientnet_model.py:143] round_filter input=40 output=48
# I0731 02:47:03.820968 134708137824896 efficientnet_model.py:143] round_filter input=40 output=48
# I0731 02:47:03.821192 134708137824896 efficientnet_model.py:143] round_filter input=80 output=96
# I0731 02:47:04.539099 134708137824896 efficientnet_model.py:143] round_filter input=80 output=96
# I0731 02:47:04.539309 134708137824896 efficientnet_model.py:143] round_filter input=112 output=136
# I0731 02:47:05.275850 134708137824896 efficientnet_model.py:143] round_filter input=112 output=136
# I0731 02:47:05.276075 134708137824896 efficientnet_model.py:143] round_filter input=192 output=232
# I0731 02:47:06.176278 134708137824896 efficientnet_model.py:143] round_filter input=192 output=232
# I0731 02:47:06.176501 134708137824896 efficientnet_model.py:143] round_filter input=320 output=384
# I0731 02:47:06.505737 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=1536
# I0731 02:47:06.572646 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 02:47:06.694440 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0731 02:47:06.694645 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 224
# I0731 02:47:06.694736 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0731 02:47:06.697959 134708137824896 efficientnet_model.py:143] round_filter input=32 output=48
# I0731 02:47:06.729646 134708137824896 efficientnet_model.py:143] round_filter input=32 output=48
# I0731 02:47:06.729784 134708137824896 efficientnet_model.py:143] round_filter input=16 output=24
# I0731 02:47:06.961237 134708137824896 efficientnet_model.py:143] round_filter input=16 output=24
# I0731 02:47:06.961440 134708137824896 efficientnet_model.py:143] round_filter input=24 output=32
# I0731 02:47:07.536414 134708137824896 efficientnet_model.py:143] round_filter input=24 output=32
# I0731 02:47:07.536689 134708137824896 efficientnet_model.py:143] round_filter input=40 output=56
# I0731 02:47:08.459112 134708137824896 efficientnet_model.py:143] round_filter input=40 output=56
# I0731 02:47:08.459312 134708137824896 efficientnet_model.py:143] round_filter input=80 output=112
# I0731 02:47:09.343485 134708137824896 efficientnet_model.py:143] round_filter input=80 output=112
# I0731 02:47:09.343652 134708137824896 efficientnet_model.py:143] round_filter input=112 output=160
# I0731 02:47:09.915513 134708137824896 efficientnet_model.py:143] round_filter input=112 output=160
# I0731 02:47:09.915683 134708137824896 efficientnet_model.py:143] round_filter input=192 output=272
# I0731 02:47:10.700365 134708137824896 efficientnet_model.py:143] round_filter input=192 output=272
# I0731 02:47:10.700551 134708137824896 efficientnet_model.py:143] round_filter input=320 output=448
# I0731 02:47:10.900284 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=1792
# I0731 02:47:10.942729 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 02:47:11.021278 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0731 02:47:11.021427 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0731 02:47:11.021499 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0731 02:47:11.023299 134708137824896 efficientnet_model.py:143] round_filter input=32 output=48
# I0731 02:47:11.041355 134708137824896 efficientnet_model.py:143] round_filter input=32 output=48
# I0731 02:47:11.041468 134708137824896 efficientnet_model.py:143] round_filter input=16 output=24
# I0731 02:47:11.275971 134708137824896 efficientnet_model.py:143] round_filter input=16 output=24
# I0731 02:47:11.276113 134708137824896 efficientnet_model.py:143] round_filter input=24 output=40
# I0731 02:47:11.742021 134708137824896 efficientnet_model.py:143] round_filter input=24 output=40
# I0731 02:47:11.742183 134708137824896 efficientnet_model.py:143] round_filter input=40 output=64
# I0731 02:47:12.242300 134708137824896 efficientnet_model.py:143] round_filter input=40 output=64
# I0731 02:47:12.242472 134708137824896 efficientnet_model.py:143] round_filter input=80 output=128
# I0731 02:47:12.905591 134708137824896 efficientnet_model.py:143] round_filter input=80 output=128
# I0731 02:47:12.905754 134708137824896 efficientnet_model.py:143] round_filter input=112 output=176
# I0731 02:47:13.584929 134708137824896 efficientnet_model.py:143] round_filter input=112 output=176
# I0731 02:47:13.585138 134708137824896 efficientnet_model.py:143] round_filter input=192 output=304
# I0731 02:47:14.447570 134708137824896 efficientnet_model.py:143] round_filter input=192 output=304
# I0731 02:47:14.447753 134708137824896 efficientnet_model.py:143] round_filter input=320 output=512
# I0731 02:47:14.775214 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0731 02:47:14.814151 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 02:47:14.910092 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0731 02:47:14.910233 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0731 02:47:14.910306 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0731 02:47:14.912116 134708137824896 efficientnet_model.py:143] round_filter input=32 output=56
# I0731 02:47:14.933147 134708137824896 efficientnet_model.py:143] round_filter input=32 output=56
# I0731 02:47:14.933272 134708137824896 efficientnet_model.py:143] round_filter input=16 output=32
# I0731 02:47:15.205200 134708137824896 efficientnet_model.py:143] round_filter input=16 output=32
# I0731 02:47:15.205366 134708137824896 efficientnet_model.py:143] round_filter input=24 output=40
# I0731 02:47:15.794966 134708137824896 efficientnet_model.py:143] round_filter input=24 output=40
# I0731 02:47:15.795126 134708137824896 efficientnet_model.py:143] round_filter input=40 output=72
# I0731 02:47:16.363104 134708137824896 efficientnet_model.py:143] round_filter input=40 output=72
# I0731 02:47:16.363296 134708137824896 efficientnet_model.py:143] round_filter input=80 output=144
# I0731 02:47:17.405411 134708137824896 efficientnet_model.py:143] round_filter input=80 output=144
# I0731 02:47:17.405565 134708137824896 efficientnet_model.py:143] round_filter input=112 output=200
# I0731 02:47:18.174226 134708137824896 efficientnet_model.py:143] round_filter input=112 output=200
# I0731 02:47:18.174395 134708137824896 efficientnet_model.py:143] round_filter input=192 output=344
# I0731 02:47:19.230204 134708137824896 efficientnet_model.py:143] round_filter input=192 output=344
# I0731 02:47:19.230373 134708137824896 efficientnet_model.py:143] round_filter input=320 output=576
# I0731 02:47:19.655492 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0731 02:47:19.708670 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0731 02:47:19.894312 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0731 02:47:19.894514 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0731 02:47:19.894592 134708137824896 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0731 02:47:19.897510 134708137824896 efficientnet_model.py:143] round_filter input=32 output=64
# I0731 02:47:19.925899 134708137824896 efficientnet_model.py:143] round_filter input=32 output=64
# I0731 02:47:19.926036 134708137824896 efficientnet_model.py:143] round_filter input=16 output=32
# I0731 02:47:20.363096 134708137824896 efficientnet_model.py:143] round_filter input=16 output=32
# I0731 02:47:20.363286 134708137824896 efficientnet_model.py:143] round_filter input=24 output=48
# I0731 02:47:21.300178 134708137824896 efficientnet_model.py:143] round_filter input=24 output=48
# I0731 02:47:21.301251 134708137824896 efficientnet_model.py:143] round_filter input=40 output=80
# I0731 02:47:22.292480 134708137824896 efficientnet_model.py:143] round_filter input=40 output=80
# I0731 02:47:22.292685 134708137824896 efficientnet_model.py:143] round_filter input=80 output=160
# I0731 02:47:23.751744 134708137824896 efficientnet_model.py:143] round_filter input=80 output=160
# I0731 02:47:23.751956 134708137824896 efficientnet_model.py:143] round_filter input=112 output=224
# I0731 02:47:25.188760 134708137824896 efficientnet_model.py:143] round_filter input=112 output=224
# I0731 02:47:25.188979 134708137824896 efficientnet_model.py:143] round_filter input=192 output=384
# I0731 02:47:27.184608 134708137824896 efficientnet_model.py:143] round_filter input=192 output=384
# I0731 02:47:27.184813 134708137824896 efficientnet_model.py:143] round_filter input=320 output=640
# I0731 02:47:27.827229 134708137824896 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0731 02:47:27.886631 134708137824896 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 38.74s
# I0731 02:47:28.086106 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 38.74s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# I0731 02:47:28.126897 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.01s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0731 02:47:28.129409 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0731 02:47:28.130038 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0731 02:47:28.132136 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0731 02:47:28.134000 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0731 02:47:28.134526 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0731 02:47:28.135911 134708137824896 test_util.py:2462] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 54.670s
#
# OK (skipped=1)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.13.0

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=3b6522d62dd9ff6e5a606670ee9485fcc2c64fd928d00a576915521b10fab4b2
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import object_detection
import wget

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2023-07-31 02:47:39--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 173.194.69.128, 2a00:1450:4013:c04::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|173.194.69.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20518283 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.57M  31.5MB/s    in 0.6s
#
# 2023-07-31 02:47:40 (31.5 MB/s) - ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’ saved [20518283/20518283]
#
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# Createing label map

# %%
labels = [{'name':'chickoo', 'id':1}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %%
#Need to be only used if we run on google colab
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}
# Out:
# Tensorflow/workspace/images/train/
# Tensorflow/workspace/images/train/chickoo.000001.jpg
# Tensorflow/workspace/images/train/chickoo.000001.xml
# Tensorflow/workspace/images/train/chickoo.000002.jpg
# Tensorflow/workspace/images/train/chickoo.000002.xml
# Tensorflow/workspace/images/train/chickoo.000003.jpg
# Tensorflow/workspace/images/train/chickoo.000003.xml
# Tensorflow/workspace/images/train/chickoo.000004.jpg
# Tensorflow/workspace/images/train/chickoo.000004.xml
# Tensorflow/workspace/images/train/chickoo.000005.jpg
# Tensorflow/workspace/images/train/chickoo.000005.xml
# Tensorflow/workspace/images/train/chickoo.000006.jpg
# Tensorflow/workspace/images/train/chickoo.000006.xml
# Tensorflow/workspace/images/train/chickoo.000007.jpg
# Tensorflow/workspace/images/train/chickoo.000007.xml
# Tensorflow/workspace/images/train/chickoo.000008.jpg
# Tensorflow/workspace/images/train/chickoo.000008.xml
# Tensorflow/workspace/images/train/chickoo.000009.jpg
# Tensorflow/workspace/images/train/chickoo.000009.xml
# Tensorflow/workspace/images/train/chickoo.000012.jpg
# Tensorflow/workspace/images/train/chickoo.000012.xml
# Tensorflow/workspace/images/train/chickoo.000013.jpg
# Tensorflow/workspace/images/train/chickoo.000013.xml
# Tensorflow/workspace/images/train/chickoo.000014.jpg
# Tensorflow/workspace/images/train/chickoo.000014.xml
# Tensorflow/workspace/images/train/chickoo.000015.jpg
# Tensorflow/workspace/images/train/chickoo.000015.xml
# Tensorflow/workspace/images/train/chickoo.000016.jpg
# Tensorflow/workspace/images/train/chickoo.000016.xml
# Tensorflow/workspace/images/train/chickoo.000017.jpg
# Tensorflow/workspace/images/train/chickoo.000017.xml
# Tensorflow/workspace/images/train/chickoo.000018.jpg
# Tensorflow/workspace/images/train/chickoo.000018.xml
# Tensorflow/workspace/images/train/chickoo.000019.jpg
# Tensorflow/workspace/images/train/chickoo.000019.xml
# Tensorflow/workspace/images/train/chickoo.000020.jpg
# Tensorflow/workspace/images/train/chickoo.000020.xml
# Tensorflow/workspace/images/train/chickoo.000021.jpg
# Tensorflow/workspace/images/train/chickoo.000021.xml
# Tensorflow/workspace/images/train/chickoo.000022.jpg
# Tensorflow/workspace/images/train/chickoo.000022.xml
# Tensorflow/workspace/images/train/chickoo.000023.jpg
# Tensorflow/workspace/images/train/chickoo.000023.xml
# Tensorflow/workspace/images/train/chickoo.000024.jpg
# Tensorflow/workspace/images/train/chickoo.000024.xml
# Tensorflow/workspace/images/train/chickoo.000025.jpg
# Tensorflow/workspace/images/train/chickoo.000025.xml
# Tensorflow/workspace/images/train/chickoo.000026.jpg
# Tensorflow/workspace/images/train/chickoo.000026.xml
# Tensorflow/workspace/images/train/chickoo.000027.jpg
# Tensorflow/workspace/images/train/chickoo.000027.xml
# Tensorflow/workspace/images/train/chickoo.000028.jpg
# Tensorflow/workspace/images/train/chickoo.000028.xml
# Tensorflow/workspace/images/train/chickoo.000029.jpg
# Tensorflow/workspace/images/train/chickoo.000029.xml
# Tensorflow/workspace/images/train/chickoo.000030.jpg
# Tensorflow/workspace/images/train/chickoo.000030.xml
# Tensorflow/workspace/images/train/chickoo.000031.jpg
# Tensorflow/workspace/images/train/chickoo.000031.xml
# Tensorflow/workspace/images/train/chickoo.000032.jpg
# Tensorflow/workspace/images/train/chickoo.000032.xml
# Tensorflow/workspace/images/train/chickoo.000033.jpg
# Tensorflow/workspace/images/train/chickoo.000033.xml
# Tensorflow/workspace/images/train/chickoo.000034.jpg
# Tensorflow/workspace/images/train/chickoo.000034.xml
# Tensorflow/workspace/images/train/chickoo.000035.jpg
# Tensorflow/workspace/images/train/chickoo.000035.xml
# Tensorflow/workspace/images/train/chickoo.000036.jpg
# Tensorflow/workspace/images/train/chickoo.000036.xml
# Tensorflow/workspace/images/train/chickoo.000037.jpg
# Tensorflow/workspace/images/train/chickoo.000037.xml
# Tensorflow/workspace/images/train/chickoo.000038.jpg
# Tensorflow/workspace/images/train/chickoo.000038.xml
# Tensorflow/workspace/images/train/chickoo.000039.jpg
# Tensorflow/workspace/images/train/chickoo.000039.xml
# Tensorflow/workspace/images/train/chickoo.000040.jpg
# Tensorflow/workspace/images/train/chickoo.000040.xml
# Tensorflow/workspace/images/train/chickoo.000041.jpg
# Tensorflow/workspace/images/train/chickoo.000041.xml
# Tensorflow/workspace/images/train/chickoo.000042.jpg
# Tensorflow/workspace/images/train/chickoo.000042.xml
# Tensorflow/workspace/images/train/chickoo.000043.jpg
# Tensorflow/workspace/images/train/chickoo.000043.xml
# Tensorflow/workspace/images/train/chickoo.000044.jpg
# Tensorflow/workspace/images/train/chickoo.000044.xml
# Tensorflow/workspace/images/train/chickoo.000045.jpg
# Tensorflow/workspace/images/train/chickoo.000045.xml
# Tensorflow/workspace/images/train/chickoo.000046.jpg
# Tensorflow/workspace/images/train/chickoo.000046.xml
# Tensorflow/workspace/images/train/chickoo.000047.jpg
# Tensorflow/workspace/images/train/chickoo.000047.xml
# Tensorflow/workspace/images/train/chickoo.000048.jpg
# Tensorflow/workspace/images/train/chickoo.000048.xml
# Tensorflow/workspace/images/train/chickoo.000049.jpg
# Tensorflow/workspace/images/train/chickoo.000049.xml
# Tensorflow/workspace/images/train/chickoo.000050.jpg
# Tensorflow/workspace/images/train/chickoo.000050.xml
# Tensorflow/workspace/images/train/chickoo.000051.jpg
# Tensorflow/workspace/images/train/chickoo.000051.xml
# Tensorflow/workspace/images/train/chickoo.000052.jpg
# Tensorflow/workspace/images/train/chickoo.000052.xml
# Tensorflow/workspace/images/train/chickoo.000053.jpg
# Tensorflow/workspace/images/train/chickoo.000053.xml
# Tensorflow/workspace/images/train/chickoo.000054.jpg
# Tensorflow/workspace/images/train/chickoo.000054.xml
# Tensorflow/workspace/images/train/chickoo.000055.jpg
# Tensorflow/workspace/images/train/chickoo.000055.xml
# Tensorflow/workspace/images/train/chickoo.000056.jpg
# Tensorflow/workspace/images/train/chickoo.000056.xml
# Tensorflow/workspace/images/train/chickoo.000057.jpg
# Tensorflow/workspace/images/train/chickoo.000057.xml
# Tensorflow/workspace/images/train/chickoo.000058.jpg
# Tensorflow/workspace/images/train/chickoo.000058.xml
# Tensorflow/workspace/images/train/chickoo.000059.jpg
# Tensorflow/workspace/images/train/chickoo.000059.xml
# Tensorflow/workspace/images/train/chickoo.000060.jpg
# Tensorflow/workspace/images/train/chickoo.000060.xml
# Tensorflow/workspace/images/train/chickoo.000061.jpg
# Tensorflow/workspace/images/train/chickoo.000061.xml
# Tensorflow/workspace/images/train/chickoo.000062.jpg
# Tensorflow/workspace/images/train/chickoo.000062.xml
# Tensorflow/workspace/images/train/chickoo.000063.jpg
# Tensorflow/workspace/images/train/chickoo.000063.xml
# Tensorflow/workspace/images/train/chickoo.000064.jpg
# Tensorflow/workspace/images/train/chickoo.000064.xml
# Tensorflow/workspace/images/train/chickoo.000065.jpg
# Tensorflow/workspace/images/train/chickoo.000065.xml
# Tensorflow/workspace/images/train/chickoo.000066.jpg
# Tensorflow/workspace/images/train/chickoo.000066.xml
# Tensorflow/workspace/images/train/chickoo.000067.jpg
# Tensorflow/workspace/images/train/chickoo.000067.xml
# Tensorflow/workspace/images/train/chickoo.000068.jpg
# Tensorflow/workspace/images/train/chickoo.000068.xml
# Tensorflow/workspace/images/train/chickoo.000069.jpg
# Tensorflow/workspace/images/train/chickoo.000069.xml
# Tensorflow/workspace/images/train/chickoo.000070.jpg
# Tensorflow/workspace/images/train/chickoo.000070.xml
# Tensorflow/workspace/images/train/chickoo.000071.jpg
# Tensorflow/workspace/images/train/chickoo.000071.xml
# Tensorflow/workspace/images/train/chickoo.000072.jpg
# Tensorflow/workspace/images/train/chickoo.000072.xml
# Tensorflow/workspace/images/train/chickoo.000073.jpg
# Tensorflow/workspace/images/train/chickoo.000073.xml
# Tensorflow/workspace/images/train/chickoo.000074.jpg
# Tensorflow/workspace/images/train/chickoo.000074.xml
# Tensorflow/workspace/images/train/chickoo.000075.jpg
# Tensorflow/workspace/images/train/chickoo.000075.xml
# Tensorflow/workspace/images/train/chickoo.000076.jpg
# Tensorflow/workspace/images/train/chickoo.000076.xml
# Tensorflow/workspace/images/train/chickoo.000077.jpg
# Tensorflow/workspace/images/train/chickoo.000077.xml
# Tensorflow/workspace/images/train/chickoo.000078.jpg
# Tensorflow/workspace/images/train/chickoo.000078.xml
# Tensorflow/workspace/images/train/chickoo.000079.jpg
# Tensorflow/workspace/images/train/chickoo.000079.xml
# Tensorflow/workspace/images/train/chickoo.000080.jpg
# Tensorflow/workspace/images/train/chickoo.000080.xml
# Tensorflow/workspace/images/train/chickoo.000081.jpg
# Tensorflow/workspace/images/train/chickoo.000081.xml
# Tensorflow/workspace/images/train/chickoo.000082.jpg
# Tensorflow/workspace/images/train/chickoo.000082.xml
# Tensorflow/workspace/images/train/chickoo.000083.jpg
# Tensorflow/workspace/images/train/chickoo.000083.xml
# Tensorflow/workspace/images/train/chickoo.000084.jpg
# Tensorflow/workspace/images/train/chickoo.000084.xml
# Tensorflow/workspace/images/train/chickoo.000085.jpg
# Tensorflow/workspace/images/train/chickoo.000085.xml
# Tensorflow/workspace/images/train/chickoo.000086.jpg
# Tensorflow/workspace/images/train/chickoo.000086.xml
# Tensorflow/workspace/images/train/chickoo.000087.jpg
# Tensorflow/workspace/images/train/chickoo.000087.xml
# Tensorflow/workspace/images/train/chickoo.000088.jpg
# Tensorflow/workspace/images/train/chickoo.000088.xml
# Tensorflow/workspace/images/train/chickoo.000089.jpg
# Tensorflow/workspace/images/train/chickoo.000089.xml
# Tensorflow/workspace/images/train/chickoo.000090.jpg
# Tensorflow/workspace/images/train/chickoo.000090.xml
# Tensorflow/workspace/images/train/chickoo.000091.jpg
# Tensorflow/workspace/images/train/chickoo.000091.xml
# Tensorflow/workspace/images/train/chickoo.000092.jpg
# Tensorflow/workspace/images/train/chickoo.000092.xml
# Tensorflow/workspace/images/train/chickoo.000093.jpg
# Tensorflow/workspace/images/train/chickoo.000093.xml
# Tensorflow/workspace/images/train/chickoo.000094.jpg
# Tensorflow/workspace/images/train/chickoo.000094.xml
# Tensorflow/workspace/images/train/chickoo.000095.jpg
# Tensorflow/workspace/images/train/chickoo.000095.xml
# Tensorflow/workspace/images/train/chickoo.000096.jpg
# Tensorflow/workspace/images/train/chickoo.000096.xml
# Tensorflow/workspace/images/train/chickoo.000097.jpg
# Tensorflow/workspace/images/train/chickoo.000097.xml
# Tensorflow/workspace/images/train/chickoo.000098.jpg
# Tensorflow/workspace/images/train/chickoo.000098.xml
# Tensorflow/workspace/images/train/chickoo.000099.jpg
# Tensorflow/workspace/images/train/chickoo.000099.xml
# Tensorflow/workspace/images/train/chickoo.000100.jpg
# Tensorflow/workspace/images/train/chickoo.000100.xml
# Tensorflow/workspace/images/train/chickoo.000101.jpg
# Tensorflow/workspace/images/train/chickoo.000101.xml
# Tensorflow/workspace/images/train/chickoo.000102.jpg
# Tensorflow/workspace/images/train/chickoo.000102.xml
# Tensorflow/workspace/images/train/chickoo.000103.jpg
# Tensorflow/workspace/images/train/chickoo.000103.xml
# Tensorflow/workspace/images/train/chickoo.000104.jpg
# Tensorflow/workspace/images/train/chickoo.000104.xml
# Tensorflow/workspace/images/train/chickoo.000105.jpg
# Tensorflow/workspace/images/train/chickoo.000105.xml
# Tensorflow/workspace/images/train/chickoo.000106.jpg
# Tensorflow/workspace/images/train/chickoo.000106.xml
# Tensorflow/workspace/images/train/chickoo.000107.jpg
# Tensorflow/workspace/images/train/chickoo.000107.xml
# Tensorflow/workspace/images/train/chickoo.000108.jpg
# Tensorflow/workspace/images/train/chickoo.000108.xml
# Tensorflow/workspace/images/train/chickoo.000109.jpg
# Tensorflow/workspace/images/train/chickoo.000109.xml
# Tensorflow/workspace/images/train/chickoo.000110.jpg
# Tensorflow/workspace/images/train/chickoo.000110.xml
# Tensorflow/workspace/images/train/chickoo.000111.jpg
# Tensorflow/workspace/images/train/chickoo.000111.xml
# Tensorflow/workspace/images/train/chickoo.000112.jpg
# Tensorflow/workspace/images/train/chickoo.000112.xml
# Tensorflow/workspace/images/train/chickoo.000113.jpg
# Tensorflow/workspace/images/train/chickoo.000113.xml
# Tensorflow/workspace/images/train/chickoo.000114.jpg
# Tensorflow/workspace/images/train/chickoo.000114.xml
# Tensorflow/workspace/images/train/chickoo.000115.jpg
# Tensorflow/workspace/images/train/chickoo.000115.xml
# Tensorflow/workspace/images/train/chickoo.000116.jpg
# Tensorflow/workspace/images/train/chickoo.000116.xml
# Tensorflow/workspace/images/train/chickoo.000117.jpg
# Tensorflow/workspace/images/train/chickoo.000117.xml
# Tensorflow/workspace/images/train/chickoo.000118.jpg
# Tensorflow/workspace/images/train/chickoo.000118.xml
# Tensorflow/workspace/images/train/chickoo.000119.jpg
# Tensorflow/workspace/images/train/chickoo.000119.xml
# Tensorflow/workspace/images/train/chickoo.000120.jpg
# Tensorflow/workspace/images/train/chickoo.000120.xml
# Tensorflow/workspace/images/train/chickoo.000121.jpg
# Tensorflow/workspace/images/train/chickoo.000121.xml
# Tensorflow/workspace/images/train/chickoo.000122.jpg
# Tensorflow/workspace/images/train/chickoo.000122.xml
# Tensorflow/workspace/images/train/chickoo.000123.jpg
# Tensorflow/workspace/images/train/chickoo.000123.xml
# Tensorflow/workspace/images/train/chickoo.000124.jpg
# Tensorflow/workspace/images/train/chickoo.000124.xml
# Tensorflow/workspace/images/train/chickoo.000125.jpg
# Tensorflow/workspace/images/train/chickoo.000125.xml
# Tensorflow/workspace/images/train/chickoo.000126.jpg
# Tensorflow/workspace/images/train/chickoo.000126.xml
# Tensorflow/workspace/images/train/chickoo.000127.jpg
# Tensorflow/workspace/images/train/chickoo.000127.xml
# Tensorflow/workspace/images/train/chickoo.000128.jpg
# Tensorflow/workspace/images/train/chickoo.000128.xml
# Tensorflow/workspace/images/train/chickoo.000129.jpg
# Tensorflow/workspace/images/train/chickoo.000129.xml
# Tensorflow/workspace/images/train/chickoo.000130.jpg
# Tensorflow/workspace/images/train/chickoo.000130.xml
# Tensorflow/workspace/images/train/chickoo.000131.jpg
# Tensorflow/workspace/images/train/chickoo.000131.xml
# Tensorflow/workspace/images/train/chickoo.000132.jpg
# Tensorflow/workspace/images/train/chickoo.000132.xml
# Tensorflow/workspace/images/train/chickoo.000133.jpg
# Tensorflow/workspace/images/train/chickoo.000133.xml
# Tensorflow/workspace/images/train/chickoo.000134.jpg
# Tensorflow/workspace/images/train/chickoo.000134.xml
# Tensorflow/workspace/images/train/chickoo.000135.jpg
# Tensorflow/workspace/images/train/chickoo.000135.xml
# Tensorflow/workspace/images/train/chickoo.000136.jpg
# Tensorflow/workspace/images/train/chickoo.000136.xml
# Tensorflow/workspace/images/train/chickoo.000137.jpg
# Tensorflow/workspace/images/train/chickoo.000137.xml
# Tensorflow/workspace/images/train/chickoo.000138.jpg
# Tensorflow/workspace/images/train/chickoo.000138.xml
# Tensorflow/workspace/images/train/chickoo.000140.jpg
# Tensorflow/workspace/images/train/chickoo.000140.xml
# Tensorflow/workspace/images/train/chickoo.000141.jpg
# Tensorflow/workspace/images/train/chickoo.000141.xml
# Tensorflow/workspace/images/train/chickoo.000142.jpg
# Tensorflow/workspace/images/train/chickoo.000142.xml
# Tensorflow/workspace/images/train/chickoo.000143.jpg
# Tensorflow/workspace/images/train/chickoo.000143.xml
# Tensorflow/workspace/images/train/chickoo.000144.jpg
# Tensorflow/workspace/images/train/chickoo.000144.xml
# Tensorflow/workspace/images/train/chickoo.000145.jpg
# Tensorflow/workspace/images/train/chickoo.000145.xml
# Tensorflow/workspace/images/train/chickoo.000146.jpg
# Tensorflow/workspace/images/train/chickoo.000146.xml
# Tensorflow/workspace/images/train/chickoo.000147.jpg
# Tensorflow/workspace/images/train/chickoo.000147.xml
# Tensorflow/workspace/images/train/chickoo.000148.jpg
# Tensorflow/workspace/images/train/chickoo.000148.xml
# Tensorflow/workspace/images/train/chickoo.000149.jpg
# Tensorflow/workspace/images/train/chickoo.000149.xml
# Tensorflow/workspace/images/test/
# Tensorflow/workspace/images/test/chickoo.000001.jpg
# Tensorflow/workspace/images/test/chickoo.000001.xml
# Tensorflow/workspace/images/test/chickoo.000010.jpg
# Tensorflow/workspace/images/test/chickoo.000010.xml
# Tensorflow/workspace/images/test/chickoo.000011.jpg
# Tensorflow/workspace/images/test/chickoo.000011.xml
# Tensorflow/workspace/images/test/chickoo.000021.jpg
# Tensorflow/workspace/images/test/chickoo.000021.xml
# Tensorflow/workspace/images/test/chickoo.000139.jpg
# Tensorflow/workspace/images/test/chickoo.000139.xml

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow/scripts'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')}
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# Updateing configuration for transfer learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 5
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:
    f.write(config_text)

# %% [markdown]
# Training Model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=5000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.list_physical_devices('CPU')))
# Out:
# Num GPUs Available:  1
# Num CPUs Available:  1

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5 --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/pipeline.config --num_train_steps=5000

# %%
#tf.compat.v1.ConfigProto( device_count = {'GPU': 1 , 'CPU': 2})

# %%
# !{command}
# Out:
# 2023-07-31 02:47:58.696890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-07-31 02:48:08.079099: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0731 02:48:08.086308 132562980921984 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 5000
# I0731 02:48:08.162934 132562980921984 config_util.py:552] Maybe overwriting train_steps: 5000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0731 02:48:08.163286 132562980921984 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0731 02:48:08.897294 132562980921984 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0731 02:48:08.925297 132562980921984 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0731 02:48:08.940644 132562980921984 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0731 02:48:08.940787 132562980921984 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0731 02:48:08.940865 132562980921984 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0731 02:48:08.979263 132562980921984 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0731 02:48:09.089631 132562980921984 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0731 02:48:19.203769 132562980921984 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0731 02:48:21.820934 132562980921984 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0731 02:48:23.429900 132562980921984 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2023-07-31 02:48:27.242516: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 23040000 exceeds 10% of free system memory.
# 2023-07-31 02:48:27.262282: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 23040000 exceeds 10% of free system memory.
# 2023-07-31 02:48:27.299593: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 17505360 exceeds 10% of free system memory.
# 2023-07-31 02:48:27.334057: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 17505360 exceeds 10% of free system memory.
# 2023-07-31 02:48:27.394545: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 23040000 exceeds 10% of free system memory.
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0731 02:48:38.347856 132558013298240 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0731 02:48:46.108850 132558013298240 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.451898 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.454486 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.455583 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.456497 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.460092 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.461062 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.462005 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.462879 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.467357 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0731 02:49:00.468258 132562980921984 cross_device_ops.py:617] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0731 02:49:01.887592 132558109005376 deprecation.py:569] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0731 02:49:02.969853 132558109005376 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0731 02:49:08.549887 132558109005376 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0731 02:49:16.215019 132558109005376 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0731 02:49:23.274414 132558109005376 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# INFO:tensorflow:Step 100 per-step time 0.679s
# I0731 02:50:09.408179 132562980921984 model_lib_v2.py:705] Step 100 per-step time 0.679s
# INFO:tensorflow:{'Loss/classification_loss': 0.16037905,
#  'Loss/localization_loss': 0.11561895,
#  'Loss/regularization_loss': 0.15194423,
#  'Loss/total_loss': 0.42794222,
#  'learning_rate': 0.0319994}
# I0731 02:50:09.408550 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.16037905,
#  'Loss/localization_loss': 0.11561895,
#  'Loss/regularization_loss': 0.15194423,
#  'Loss/total_loss': 0.42794222,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.259s
# I0731 02:50:35.297025 132562980921984 model_lib_v2.py:705] Step 200 per-step time 0.259s
# INFO:tensorflow:{'Loss/classification_loss': 0.21745716,
#  'Loss/localization_loss': 0.073422894,
#  'Loss/regularization_loss': 0.15167223,
#  'Loss/total_loss': 0.44255227,
#  'learning_rate': 0.0373328}
# I0731 02:50:35.297336 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.21745716,
#  'Loss/localization_loss': 0.073422894,
#  'Loss/regularization_loss': 0.15167223,
#  'Loss/total_loss': 0.44255227,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.263s
# I0731 02:51:01.615725 132562980921984 model_lib_v2.py:705] Step 300 per-step time 0.263s
# INFO:tensorflow:{'Loss/classification_loss': 0.13182114,
#  'Loss/localization_loss': 0.07535586,
#  'Loss/regularization_loss': 0.1513406,
#  'Loss/total_loss': 0.3585176,
#  'learning_rate': 0.0426662}
# I0731 02:51:01.616109 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.13182114,
#  'Loss/localization_loss': 0.07535586,
#  'Loss/regularization_loss': 0.1513406,
#  'Loss/total_loss': 0.3585176,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.268s
# I0731 02:51:28.440567 132562980921984 model_lib_v2.py:705] Step 400 per-step time 0.268s
# INFO:tensorflow:{'Loss/classification_loss': 0.07197321,
#  'Loss/localization_loss': 0.027880361,
#  'Loss/regularization_loss': 0.15101634,
#  'Loss/total_loss': 0.25086993,
#  'learning_rate': 0.047999598}
# I0731 02:51:28.442116 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.07197321,
#  'Loss/localization_loss': 0.027880361,
#  'Loss/regularization_loss': 0.15101634,
#  'Loss/total_loss': 0.25086993,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.266s
# I0731 02:51:55.001662 132562980921984 model_lib_v2.py:705] Step 500 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.07777379,
#  'Loss/localization_loss': 0.031985924,
#  'Loss/regularization_loss': 0.15054962,
#  'Loss/total_loss': 0.26030934,
#  'learning_rate': 0.053333}
# I0731 02:51:55.003409 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.07777379,
#  'Loss/localization_loss': 0.031985924,
#  'Loss/regularization_loss': 0.15054962,
#  'Loss/total_loss': 0.26030934,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.265s
# I0731 02:52:21.472851 132562980921984 model_lib_v2.py:705] Step 600 per-step time 0.265s
# INFO:tensorflow:{'Loss/classification_loss': 0.06776088,
#  'Loss/localization_loss': 0.026541678,
#  'Loss/regularization_loss': 0.15001483,
#  'Loss/total_loss': 0.24431738,
#  'learning_rate': 0.0586664}
# I0731 02:52:21.473272 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.06776088,
#  'Loss/localization_loss': 0.026541678,
#  'Loss/regularization_loss': 0.15001483,
#  'Loss/total_loss': 0.24431738,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.266s
# I0731 02:52:48.114266 132562980921984 model_lib_v2.py:705] Step 700 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.06611828,
#  'Loss/localization_loss': 0.044588298,
#  'Loss/regularization_loss': 0.14945284,
#  'Loss/total_loss': 0.2601594,
#  'learning_rate': 0.0639998}
# I0731 02:52:48.114911 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.06611828,
#  'Loss/localization_loss': 0.044588298,
#  'Loss/regularization_loss': 0.14945284,
#  'Loss/total_loss': 0.2601594,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.267s
# I0731 02:53:14.805267 132562980921984 model_lib_v2.py:705] Step 800 per-step time 0.267s
# INFO:tensorflow:{'Loss/classification_loss': 0.07969499,
#  'Loss/localization_loss': 0.047436763,
#  'Loss/regularization_loss': 0.14886037,
#  'Loss/total_loss': 0.2759921,
#  'learning_rate': 0.069333196}
# I0731 02:53:14.805581 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.07969499,
#  'Loss/localization_loss': 0.047436763,
#  'Loss/regularization_loss': 0.14886037,
#  'Loss/total_loss': 0.2759921,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.264s
# I0731 02:53:41.223419 132562980921984 model_lib_v2.py:705] Step 900 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.09200207,
#  'Loss/localization_loss': 0.038641658,
#  'Loss/regularization_loss': 0.14823765,
#  'Loss/total_loss': 0.27888137,
#  'learning_rate': 0.074666604}
# I0731 02:53:41.223795 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.09200207,
#  'Loss/localization_loss': 0.038641658,
#  'Loss/regularization_loss': 0.14823765,
#  'Loss/total_loss': 0.27888137,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.265s
# I0731 02:54:07.774962 132562980921984 model_lib_v2.py:705] Step 1000 per-step time 0.265s
# INFO:tensorflow:{'Loss/classification_loss': 0.031211125,
#  'Loss/localization_loss': 0.033033967,
#  'Loss/regularization_loss': 0.14755045,
#  'Loss/total_loss': 0.21179554,
#  'learning_rate': 0.08}
# I0731 02:54:07.776211 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.031211125,
#  'Loss/localization_loss': 0.033033967,
#  'Loss/regularization_loss': 0.14755045,
#  'Loss/total_loss': 0.21179554,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.289s
# I0731 02:54:36.654874 132562980921984 model_lib_v2.py:705] Step 1100 per-step time 0.289s
# INFO:tensorflow:{'Loss/classification_loss': 0.07313982,
#  'Loss/localization_loss': 0.024669675,
#  'Loss/regularization_loss': 0.14688073,
#  'Loss/total_loss': 0.24469022,
#  'learning_rate': 0.07999918}
# I0731 02:54:36.655311 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.07313982,
#  'Loss/localization_loss': 0.024669675,
#  'Loss/regularization_loss': 0.14688073,
#  'Loss/total_loss': 0.24469022,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.266s
# I0731 02:55:03.202310 132562980921984 model_lib_v2.py:705] Step 1200 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.10477622,
#  'Loss/localization_loss': 0.04952841,
#  'Loss/regularization_loss': 0.14612724,
#  'Loss/total_loss': 0.30043185,
#  'learning_rate': 0.079996705}
# I0731 02:55:03.202628 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.10477622,
#  'Loss/localization_loss': 0.04952841,
#  'Loss/regularization_loss': 0.14612724,
#  'Loss/total_loss': 0.30043185,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.262s
# I0731 02:55:29.443539 132562980921984 model_lib_v2.py:705] Step 1300 per-step time 0.262s
# INFO:tensorflow:{'Loss/classification_loss': 0.05078389,
#  'Loss/localization_loss': 0.016061537,
#  'Loss/regularization_loss': 0.14536066,
#  'Loss/total_loss': 0.2122061,
#  'learning_rate': 0.0799926}
# I0731 02:55:29.443850 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.05078389,
#  'Loss/localization_loss': 0.016061537,
#  'Loss/regularization_loss': 0.14536066,
#  'Loss/total_loss': 0.2122061,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.264s
# I0731 02:55:55.858697 132562980921984 model_lib_v2.py:705] Step 1400 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.05938905,
#  'Loss/localization_loss': 0.02028968,
#  'Loss/regularization_loss': 0.14461167,
#  'Loss/total_loss': 0.2242904,
#  'learning_rate': 0.07998685}
# I0731 02:55:55.863650 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.05938905,
#  'Loss/localization_loss': 0.02028968,
#  'Loss/regularization_loss': 0.14461167,
#  'Loss/total_loss': 0.2242904,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.266s
# I0731 02:56:22.512135 132562980921984 model_lib_v2.py:705] Step 1500 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.040415272,
#  'Loss/localization_loss': 0.023776917,
#  'Loss/regularization_loss': 0.14386547,
#  'Loss/total_loss': 0.20805766,
#  'learning_rate': 0.07997945}
# I0731 02:56:22.514183 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.040415272,
#  'Loss/localization_loss': 0.023776917,
#  'Loss/regularization_loss': 0.14386547,
#  'Loss/total_loss': 0.20805766,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.266s
# I0731 02:56:49.117078 132562980921984 model_lib_v2.py:705] Step 1600 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.03838573,
#  'Loss/localization_loss': 0.012502525,
#  'Loss/regularization_loss': 0.14310353,
#  'Loss/total_loss': 0.19399178,
#  'learning_rate': 0.079970405}
# I0731 02:56:49.117470 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03838573,
#  'Loss/localization_loss': 0.012502525,
#  'Loss/regularization_loss': 0.14310353,
#  'Loss/total_loss': 0.19399178,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.266s
# I0731 02:57:15.763342 132562980921984 model_lib_v2.py:705] Step 1700 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.047603764,
#  'Loss/localization_loss': 0.011084627,
#  'Loss/regularization_loss': 0.14231431,
#  'Loss/total_loss': 0.2010027,
#  'learning_rate': 0.07995972}
# I0731 02:57:15.763782 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.047603764,
#  'Loss/localization_loss': 0.011084627,
#  'Loss/regularization_loss': 0.14231431,
#  'Loss/total_loss': 0.2010027,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.264s
# I0731 02:57:42.136494 132562980921984 model_lib_v2.py:705] Step 1800 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.041280776,
#  'Loss/localization_loss': 0.01115677,
#  'Loss/regularization_loss': 0.14155687,
#  'Loss/total_loss': 0.19399442,
#  'learning_rate': 0.0799474}
# I0731 02:57:42.136813 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.041280776,
#  'Loss/localization_loss': 0.01115677,
#  'Loss/regularization_loss': 0.14155687,
#  'Loss/total_loss': 0.19399442,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.264s
# I0731 02:58:08.518857 132562980921984 model_lib_v2.py:705] Step 1900 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.048400454,
#  'Loss/localization_loss': 0.0102138575,
#  'Loss/regularization_loss': 0.14076224,
#  'Loss/total_loss': 0.19937655,
#  'learning_rate': 0.07993342}
# I0731 02:58:08.519210 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.048400454,
#  'Loss/localization_loss': 0.0102138575,
#  'Loss/regularization_loss': 0.14076224,
#  'Loss/total_loss': 0.19937655,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.264s
# I0731 02:58:34.937975 132562980921984 model_lib_v2.py:705] Step 2000 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.040488575,
#  'Loss/localization_loss': 0.011289995,
#  'Loss/regularization_loss': 0.14000519,
#  'Loss/total_loss': 0.19178376,
#  'learning_rate': 0.07991781}
# I0731 02:58:34.938414 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.040488575,
#  'Loss/localization_loss': 0.011289995,
#  'Loss/regularization_loss': 0.14000519,
#  'Loss/total_loss': 0.19178376,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.285s
# I0731 02:59:03.458606 132562980921984 model_lib_v2.py:705] Step 2100 per-step time 0.285s
# INFO:tensorflow:{'Loss/classification_loss': 0.03958057,
#  'Loss/localization_loss': 0.01589503,
#  'Loss/regularization_loss': 0.13924134,
#  'Loss/total_loss': 0.19471693,
#  'learning_rate': 0.07990056}
# I0731 02:59:03.459000 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03958057,
#  'Loss/localization_loss': 0.01589503,
#  'Loss/regularization_loss': 0.13924134,
#  'Loss/total_loss': 0.19471693,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.266s
# I0731 02:59:30.110712 132562980921984 model_lib_v2.py:705] Step 2200 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.041255057,
#  'Loss/localization_loss': 0.021113709,
#  'Loss/regularization_loss': 0.13846767,
#  'Loss/total_loss': 0.20083643,
#  'learning_rate': 0.07988167}
# I0731 02:59:30.111148 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.041255057,
#  'Loss/localization_loss': 0.021113709,
#  'Loss/regularization_loss': 0.13846767,
#  'Loss/total_loss': 0.20083643,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.263s
# I0731 02:59:56.411236 132562980921984 model_lib_v2.py:705] Step 2300 per-step time 0.263s
# INFO:tensorflow:{'Loss/classification_loss': 0.035358727,
#  'Loss/localization_loss': 0.0114878565,
#  'Loss/regularization_loss': 0.1376888,
#  'Loss/total_loss': 0.18453538,
#  'learning_rate': 0.07986114}
# I0731 02:59:56.411566 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.035358727,
#  'Loss/localization_loss': 0.0114878565,
#  'Loss/regularization_loss': 0.1376888,
#  'Loss/total_loss': 0.18453538,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.263s
# I0731 03:00:22.684950 132562980921984 model_lib_v2.py:705] Step 2400 per-step time 0.263s
# INFO:tensorflow:{'Loss/classification_loss': 0.05414963,
#  'Loss/localization_loss': 0.017948326,
#  'Loss/regularization_loss': 0.13692668,
#  'Loss/total_loss': 0.20902464,
#  'learning_rate': 0.07983897}
# I0731 03:00:22.685284 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.05414963,
#  'Loss/localization_loss': 0.017948326,
#  'Loss/regularization_loss': 0.13692668,
#  'Loss/total_loss': 0.20902464,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.264s
# I0731 03:00:49.139957 132562980921984 model_lib_v2.py:705] Step 2500 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.045891073,
#  'Loss/localization_loss': 0.008006878,
#  'Loss/regularization_loss': 0.13616014,
#  'Loss/total_loss': 0.19005808,
#  'learning_rate': 0.079815164}
# I0731 03:00:49.140360 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.045891073,
#  'Loss/localization_loss': 0.008006878,
#  'Loss/regularization_loss': 0.13616014,
#  'Loss/total_loss': 0.19005808,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.267s
# I0731 03:01:15.822950 132562980921984 model_lib_v2.py:705] Step 2600 per-step time 0.267s
# INFO:tensorflow:{'Loss/classification_loss': 0.03876834,
#  'Loss/localization_loss': 0.010812952,
#  'Loss/regularization_loss': 0.13540988,
#  'Loss/total_loss': 0.18499117,
#  'learning_rate': 0.07978972}
# I0731 03:01:15.826677 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03876834,
#  'Loss/localization_loss': 0.010812952,
#  'Loss/regularization_loss': 0.13540988,
#  'Loss/total_loss': 0.18499117,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.265s
# I0731 03:01:42.377317 132562980921984 model_lib_v2.py:705] Step 2700 per-step time 0.265s
# INFO:tensorflow:{'Loss/classification_loss': 0.028143076,
#  'Loss/localization_loss': 0.010377837,
#  'Loss/regularization_loss': 0.13464606,
#  'Loss/total_loss': 0.17316698,
#  'learning_rate': 0.07976264}
# I0731 03:01:42.377764 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.028143076,
#  'Loss/localization_loss': 0.010377837,
#  'Loss/regularization_loss': 0.13464606,
#  'Loss/total_loss': 0.17316698,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.267s
# I0731 03:02:09.040427 132562980921984 model_lib_v2.py:705] Step 2800 per-step time 0.267s
# INFO:tensorflow:{'Loss/classification_loss': 0.03089547,
#  'Loss/localization_loss': 0.02103647,
#  'Loss/regularization_loss': 0.13388933,
#  'Loss/total_loss': 0.18582126,
#  'learning_rate': 0.07973392}
# I0731 03:02:09.040812 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03089547,
#  'Loss/localization_loss': 0.02103647,
#  'Loss/regularization_loss': 0.13388933,
#  'Loss/total_loss': 0.18582126,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.264s
# I0731 03:02:35.451473 132562980921984 model_lib_v2.py:705] Step 2900 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.038178943,
#  'Loss/localization_loss': 0.025412822,
#  'Loss/regularization_loss': 0.13326928,
#  'Loss/total_loss': 0.19686104,
#  'learning_rate': 0.07970358}
# I0731 03:02:35.451785 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.038178943,
#  'Loss/localization_loss': 0.025412822,
#  'Loss/regularization_loss': 0.13326928,
#  'Loss/total_loss': 0.19686104,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.263s
# I0731 03:03:01.720260 132562980921984 model_lib_v2.py:705] Step 3000 per-step time 0.263s
# INFO:tensorflow:{'Loss/classification_loss': 0.046231333,
#  'Loss/localization_loss': 0.016291654,
#  'Loss/regularization_loss': 0.13257489,
#  'Loss/total_loss': 0.19509786,
#  'learning_rate': 0.0796716}
# I0731 03:03:01.720568 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.046231333,
#  'Loss/localization_loss': 0.016291654,
#  'Loss/regularization_loss': 0.13257489,
#  'Loss/total_loss': 0.19509786,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.277s
# I0731 03:03:29.416885 132562980921984 model_lib_v2.py:705] Step 3100 per-step time 0.277s
# INFO:tensorflow:{'Loss/classification_loss': 0.03989825,
#  'Loss/localization_loss': 0.014846953,
#  'Loss/regularization_loss': 0.1318427,
#  'Loss/total_loss': 0.1865879,
#  'learning_rate': 0.07963799}
# I0731 03:03:29.417369 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03989825,
#  'Loss/localization_loss': 0.014846953,
#  'Loss/regularization_loss': 0.1318427,
#  'Loss/total_loss': 0.1865879,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.265s
# I0731 03:03:55.971938 132562980921984 model_lib_v2.py:705] Step 3200 per-step time 0.265s
# INFO:tensorflow:{'Loss/classification_loss': 0.042125717,
#  'Loss/localization_loss': 0.0118697,
#  'Loss/regularization_loss': 0.13112386,
#  'Loss/total_loss': 0.18511927,
#  'learning_rate': 0.07960275}
# I0731 03:03:55.972363 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.042125717,
#  'Loss/localization_loss': 0.0118697,
#  'Loss/regularization_loss': 0.13112386,
#  'Loss/total_loss': 0.18511927,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.267s
# I0731 03:04:22.656662 132562980921984 model_lib_v2.py:705] Step 3300 per-step time 0.267s
# INFO:tensorflow:{'Loss/classification_loss': 0.031207852,
#  'Loss/localization_loss': 0.0073740287,
#  'Loss/regularization_loss': 0.13039333,
#  'Loss/total_loss': 0.1689752,
#  'learning_rate': 0.07956588}
# I0731 03:04:22.657248 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.031207852,
#  'Loss/localization_loss': 0.0073740287,
#  'Loss/regularization_loss': 0.13039333,
#  'Loss/total_loss': 0.1689752,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.266s
# I0731 03:04:49.204994 132562980921984 model_lib_v2.py:705] Step 3400 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.038783163,
#  'Loss/localization_loss': 0.010017961,
#  'Loss/regularization_loss': 0.12967388,
#  'Loss/total_loss': 0.178475,
#  'learning_rate': 0.079527386}
# I0731 03:04:49.205304 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.038783163,
#  'Loss/localization_loss': 0.010017961,
#  'Loss/regularization_loss': 0.12967388,
#  'Loss/total_loss': 0.178475,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.263s
# I0731 03:05:15.512687 132562980921984 model_lib_v2.py:705] Step 3500 per-step time 0.263s
# INFO:tensorflow:{'Loss/classification_loss': 0.027757594,
#  'Loss/localization_loss': 0.0077265766,
#  'Loss/regularization_loss': 0.12895125,
#  'Loss/total_loss': 0.16443542,
#  'learning_rate': 0.07948727}
# I0731 03:05:15.512990 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.027757594,
#  'Loss/localization_loss': 0.0077265766,
#  'Loss/regularization_loss': 0.12895125,
#  'Loss/total_loss': 0.16443542,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.263s
# I0731 03:05:41.878315 132562980921984 model_lib_v2.py:705] Step 3600 per-step time 0.263s
# INFO:tensorflow:{'Loss/classification_loss': 0.03137529,
#  'Loss/localization_loss': 0.0078092995,
#  'Loss/regularization_loss': 0.12823264,
#  'Loss/total_loss': 0.16741723,
#  'learning_rate': 0.079445526}
# I0731 03:05:41.878751 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03137529,
#  'Loss/localization_loss': 0.0078092995,
#  'Loss/regularization_loss': 0.12823264,
#  'Loss/total_loss': 0.16741723,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.267s
# I0731 03:06:08.576705 132562980921984 model_lib_v2.py:705] Step 3700 per-step time 0.267s
# INFO:tensorflow:{'Loss/classification_loss': 0.03475488,
#  'Loss/localization_loss': 0.010508287,
#  'Loss/regularization_loss': 0.12752102,
#  'Loss/total_loss': 0.1727842,
#  'learning_rate': 0.07940216}
# I0731 03:06:08.577193 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03475488,
#  'Loss/localization_loss': 0.010508287,
#  'Loss/regularization_loss': 0.12752102,
#  'Loss/total_loss': 0.1727842,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.266s
# I0731 03:06:35.224042 132562980921984 model_lib_v2.py:705] Step 3800 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.024972714,
#  'Loss/localization_loss': 0.010239012,
#  'Loss/regularization_loss': 0.12680432,
#  'Loss/total_loss': 0.16201605,
#  'learning_rate': 0.079357184}
# I0731 03:06:35.224636 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.024972714,
#  'Loss/localization_loss': 0.010239012,
#  'Loss/regularization_loss': 0.12680432,
#  'Loss/total_loss': 0.16201605,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.267s
# I0731 03:07:01.870827 132562980921984 model_lib_v2.py:705] Step 3900 per-step time 0.267s
# INFO:tensorflow:{'Loss/classification_loss': 0.034073245,
#  'Loss/localization_loss': 0.0059022275,
#  'Loss/regularization_loss': 0.12608284,
#  'Loss/total_loss': 0.1660583,
#  'learning_rate': 0.07931058}
# I0731 03:07:01.871129 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.034073245,
#  'Loss/localization_loss': 0.0059022275,
#  'Loss/regularization_loss': 0.12608284,
#  'Loss/total_loss': 0.1660583,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.264s
# I0731 03:07:28.254972 132562980921984 model_lib_v2.py:705] Step 4000 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.0532217,
#  'Loss/localization_loss': 0.011269636,
#  'Loss/regularization_loss': 0.12537703,
#  'Loss/total_loss': 0.18986836,
#  'learning_rate': 0.07926236}
# I0731 03:07:28.255301 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.0532217,
#  'Loss/localization_loss': 0.011269636,
#  'Loss/regularization_loss': 0.12537703,
#  'Loss/total_loss': 0.18986836,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.275s
# I0731 03:07:55.706991 132562980921984 model_lib_v2.py:705] Step 4100 per-step time 0.275s
# INFO:tensorflow:{'Loss/classification_loss': 0.03986456,
#  'Loss/localization_loss': 0.011884295,
#  'Loss/regularization_loss': 0.12469189,
#  'Loss/total_loss': 0.17644075,
#  'learning_rate': 0.07921253}
# I0731 03:07:55.707305 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03986456,
#  'Loss/localization_loss': 0.011884295,
#  'Loss/regularization_loss': 0.12469189,
#  'Loss/total_loss': 0.17644075,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.265s
# I0731 03:08:22.247422 132562980921984 model_lib_v2.py:705] Step 4200 per-step time 0.265s
# INFO:tensorflow:{'Loss/classification_loss': 0.021532414,
#  'Loss/localization_loss': 0.008270561,
#  'Loss/regularization_loss': 0.123986825,
#  'Loss/total_loss': 0.1537898,
#  'learning_rate': 0.07916109}
# I0731 03:08:22.247853 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.021532414,
#  'Loss/localization_loss': 0.008270561,
#  'Loss/regularization_loss': 0.123986825,
#  'Loss/total_loss': 0.1537898,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.266s
# I0731 03:08:48.861860 132562980921984 model_lib_v2.py:705] Step 4300 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.031493112,
#  'Loss/localization_loss': 0.007590774,
#  'Loss/regularization_loss': 0.123297565,
#  'Loss/total_loss': 0.16238146,
#  'learning_rate': 0.07910804}
# I0731 03:08:48.863584 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.031493112,
#  'Loss/localization_loss': 0.007590774,
#  'Loss/regularization_loss': 0.123297565,
#  'Loss/total_loss': 0.16238146,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.266s
# I0731 03:09:15.467778 132562980921984 model_lib_v2.py:705] Step 4400 per-step time 0.266s
# INFO:tensorflow:{'Loss/classification_loss': 0.03390491,
#  'Loss/localization_loss': 0.004567102,
#  'Loss/regularization_loss': 0.122592345,
#  'Loss/total_loss': 0.16106436,
#  'learning_rate': 0.07905338}
# I0731 03:09:15.468180 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.03390491,
#  'Loss/localization_loss': 0.004567102,
#  'Loss/regularization_loss': 0.122592345,
#  'Loss/total_loss': 0.16106436,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.264s
# I0731 03:09:41.870635 132562980921984 model_lib_v2.py:705] Step 4500 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.024343187,
#  'Loss/localization_loss': 0.0063118013,
#  'Loss/regularization_loss': 0.12189234,
#  'Loss/total_loss': 0.15254733,
#  'learning_rate': 0.07899711}
# I0731 03:09:41.871123 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.024343187,
#  'Loss/localization_loss': 0.0063118013,
#  'Loss/regularization_loss': 0.12189234,
#  'Loss/total_loss': 0.15254733,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.262s
# I0731 03:10:08.120563 132562980921984 model_lib_v2.py:705] Step 4600 per-step time 0.262s
# INFO:tensorflow:{'Loss/classification_loss': 0.039870493,
#  'Loss/localization_loss': 0.0075113303,
#  'Loss/regularization_loss': 0.12123308,
#  'Loss/total_loss': 0.16861491,
#  'learning_rate': 0.078939244}
# I0731 03:10:08.120881 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.039870493,
#  'Loss/localization_loss': 0.0075113303,
#  'Loss/regularization_loss': 0.12123308,
#  'Loss/total_loss': 0.16861491,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.263s
# I0731 03:10:34.416651 132562980921984 model_lib_v2.py:705] Step 4700 per-step time 0.263s
# INFO:tensorflow:{'Loss/classification_loss': 0.07349352,
#  'Loss/localization_loss': 0.0077593466,
#  'Loss/regularization_loss': 0.12054663,
#  'Loss/total_loss': 0.2017995,
#  'learning_rate': 0.07887978}
# I0731 03:10:34.417058 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.07349352,
#  'Loss/localization_loss': 0.0077593466,
#  'Loss/regularization_loss': 0.12054663,
#  'Loss/total_loss': 0.2017995,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.267s
# I0731 03:11:01.094674 132562980921984 model_lib_v2.py:705] Step 4800 per-step time 0.267s
# INFO:tensorflow:{'Loss/classification_loss': 0.033607095,
#  'Loss/localization_loss': 0.009651955,
#  'Loss/regularization_loss': 0.11989015,
#  'Loss/total_loss': 0.16314921,
#  'learning_rate': 0.07881871}
# I0731 03:11:01.096904 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.033607095,
#  'Loss/localization_loss': 0.009651955,
#  'Loss/regularization_loss': 0.11989015,
#  'Loss/total_loss': 0.16314921,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.264s
# I0731 03:11:27.477049 132562980921984 model_lib_v2.py:705] Step 4900 per-step time 0.264s
# INFO:tensorflow:{'Loss/classification_loss': 0.027742459,
#  'Loss/localization_loss': 0.006757893,
#  'Loss/regularization_loss': 0.11921998,
#  'Loss/total_loss': 0.15372033,
#  'learning_rate': 0.07875605}
# I0731 03:11:27.477652 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.027742459,
#  'Loss/localization_loss': 0.006757893,
#  'Loss/regularization_loss': 0.11921998,
#  'Loss/total_loss': 0.15372033,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.265s
# I0731 03:11:54.002282 132562980921984 model_lib_v2.py:705] Step 5000 per-step time 0.265s
# INFO:tensorflow:{'Loss/classification_loss': 0.030390738,
#  'Loss/localization_loss': 0.0042739254,
#  'Loss/regularization_loss': 0.11853589,
#  'Loss/total_loss': 0.15320055,
#  'learning_rate': 0.078691795}
# I0731 03:11:54.009754 132562980921984 model_lib_v2.py:708] {'Loss/classification_loss': 0.030390738,
#  'Loss/localization_loss': 0.0042739254,
#  'Loss/regularization_loss': 0.11853589,
#  'Loss/total_loss': 0.15320055,
#  'learning_rate': 0.078691795}

# %% [markdown]
# Evaluating Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5 --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5

# %%
# !{command}
# Out:
# 2023-07-31 03:11:59.434633: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0731 03:12:02.105000 135205515559552 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0731 03:12:02.105216 135205515559552 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0731 03:12:02.105300 135205515559552 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0731 03:12:02.105404 135205515559552 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0731 03:12:02.105522 135205515559552 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2023-07-31 03:12:03.041658: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# I0731 03:12:03.243748 135205515559552 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# I0731 03:12:03.243983 135205515559552 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0731 03:12:03.244073 135205515559552 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0731 03:12:03.244138 135205515559552 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0731 03:12:03.247694 135205515559552 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0731 03:12:03.266506 135205515559552 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0731 03:12:08.845143 135205515559552 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0731 03:12:10.729056 135205515559552 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5
# I0731 03:12:18.091348 135205515559552 checkpoint_utils.py:168] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5
# INFO:tensorflow:Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/ckpt-6
# I0731 03:12:18.092241 135205515559552 checkpoint_utils.py:177] Found new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/ckpt-6
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0731 03:12:23.575632 135205515559552 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0731 03:12:39.688253 135205515559552 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0731 03:12:45.674605 135205515559552 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0731 03:12:45.709229 135205515559552 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0731 03:12:46.117780 135205515559552 deprecation.py:364] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:460: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Performing evaluation on 5 images.
# I0731 03:12:59.363213 135205515559552 coco_evaluation.py:293] Performing evaluation on 5 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0731 03:12:59.363576 135205515559552 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0731 03:12:59.366216 135205515559552 coco_tools.py:138] DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.905
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.905
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.450
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.920
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.920
# INFO:tensorflow:Eval metrics at step 5000
# I0731 03:12:59.409823 135205515559552 model_lib_v2.py:1015] Eval metrics at step 5000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.905446
# I0731 03:12:59.415352 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.905446
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# I0731 03:12:59.416929 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 1.000000
# I0731 03:12:59.418336 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# I0731 03:12:59.419858 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# I0731 03:12:59.421046 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.905446
# I0731 03:12:59.426466 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.905446
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.450000
# I0731 03:12:59.427839 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.450000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.920000
# I0731 03:12:59.429243 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.920000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.920000
# I0731 03:12:59.430432 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.920000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0731 03:12:59.431590 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# I0731 03:12:59.432740 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.920000
# I0731 03:12:59.433938 135205515559552 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.920000
# INFO:tensorflow:	+ Loss/localization_loss: 0.024878
# I0731 03:12:59.434951 135205515559552 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.024878
# INFO:tensorflow:	+ Loss/classification_loss: 0.103709
# I0731 03:12:59.435971 135205515559552 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.103709
# INFO:tensorflow:	+ Loss/regularization_loss: 0.118529
# I0731 03:12:59.436991 135205515559552 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.118529
# INFO:tensorflow:	+ Loss/total_loss: 0.247116
# I0731 03:12:59.438027 135205515559552 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.247116
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5
# I0731 03:17:18.190478 135205515559552 checkpoint_utils.py:168] Waiting for new checkpoint at Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5
# INFO:tensorflow:Timed-out waiting for a checkpoint.
# I0731 04:17:17.387098 135205515559552 checkpoint_utils.py:231] Timed-out waiting for a checkpoint.

# %%
# !pip install numpy --upgrade
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.24.3)
# Collecting numpy
#   Downloading numpy-1.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 47.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# apache-beam 2.49.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.25.1 which is incompatible.
# flax 0.7.0 requires PyYAML>=5.4.1, but you have pyyaml 5.3.1 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.1 which is incompatible.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.25.1 which is incompatible.
# Successfully installed numpy-1.25.1

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %% [markdown]
# Loading the model checkpoint and detecting objects on an image

# %%
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-6')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'chickoo.000021.jpg')

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'chickoo.000139.jpg')

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'chickoo.000011.jpg')

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'train', 'chickoo.000005.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections
#print(num_detections)
# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

threshold = 0.8
object_count = 0
for x, (y_min, x_min, y_max, x_max) in enumerate(detections['detection_boxes']):
    #object_count += 1
    if detections['detection_scores'][x] > threshold:
        object_count += 1
print("number of chickoos present is",object_count)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# number of chicoos present is 2

# %% [markdown]
# Freezing the graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5 --output_directory=Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/export

# %%
# !{command}
# Out:
# 2023-07-31 04:21:52.551406: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6Status12empty_stringB5cxx11Ev']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/usr/local/lib/python3.10/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZNK10tensorflow4data11DatasetBase8FinalizeEPNS_15OpKernelContextESt8functionIFN3tsl8StatusOrISt10unique_ptrIS1_NS5_4core15RefCountDeleterEEEEvEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# 2023-07-31 04:21:55.849081: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0731 04:21:56.152127 134237902726272 deprecation.py:641] From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# I0731 04:22:00.128751 134237902726272 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0731 04:22:13.178095 134237902726272 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# I0731 04:22:15.844056 134237902726272 signature_serialization.py:148] Function `call_func` contains input name(s) resource with unsupported characters which will be renamed to weightsharedconvolutionalboxpredictor_predictiontower_conv2d_3_batchnorm_feature_4_fusedbatchnormv3_readvariableop_1_resource in the SavedModel.
# I0731 04:22:17.048680 134237902726272 api.py:460] feature_map_spatial_dims: [(80, 80), (40, 40), (20, 20), (10, 10), (5, 5)]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7a1643ff3f10>, because it is not built.
# W0731 04:22:19.060137 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7a1643ff3f10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a15f5b0b700>, because it is not built.
# W0731 04:22:19.531747 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a15f5b0b700>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16380e5630>, because it is not built.
# W0731 04:22:19.531972 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16380e5630>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16380e60b0>, because it is not built.
# W0731 04:22:19.532083 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16380e60b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a16380e5990>, because it is not built.
# W0731 04:22:19.532169 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a16380e5990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16380e6050>, because it is not built.
# W0731 04:22:19.532257 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16380e6050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16386643d0>, because it is not built.
# W0731 04:22:19.532336 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16386643d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a16386e44c0>, because it is not built.
# W0731 04:22:19.532425 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a16386e44c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638617460>, because it is not built.
# W0731 04:22:19.532504 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638617460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638616410>, because it is not built.
# W0731 04:22:19.532586 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638616410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a1638617d90>, because it is not built.
# W0731 04:22:19.532660 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7a1638617d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638617280>, because it is not built.
# W0731 04:22:19.532751 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638617280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638617640>, because it is not built.
# W0731 04:22:19.532845 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638617640>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a163888f550>, because it is not built.
# W0731 04:22:19.532927 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a163888f550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b91b70>, because it is not built.
# W0731 04:22:19.533006 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b91b70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b935b0>, because it is not built.
# W0731 04:22:19.533083 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b935b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b92a10>, because it is not built.
# W0731 04:22:19.533160 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b92a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b924d0>, because it is not built.
# W0731 04:22:19.533235 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b924d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b92f80>, because it is not built.
# W0731 04:22:19.533311 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b92f80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b92230>, because it is not built.
# W0731 04:22:19.533397 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b92230>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b93460>, because it is not built.
# W0731 04:22:19.533477 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15f5b93460>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b934f0>, because it is not built.
# W0731 04:22:19.533559 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15f5b934f0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16388721a0>, because it is not built.
# W0731 04:22:19.533638 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16388721a0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638872d10>, because it is not built.
# W0731 04:22:19.533713 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638872d10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638871fc0>, because it is not built.
# W0731 04:22:19.533801 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638871fc0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638873670>, because it is not built.
# W0731 04:22:19.533884 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638873670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16388736d0>, because it is not built.
# W0731 04:22:19.533957 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16388736d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638873820>, because it is not built.
# W0731 04:22:19.534029 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638873820>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638873280>, because it is not built.
# W0731 04:22:19.534100 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638873280>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16388708b0>, because it is not built.
# W0731 04:22:19.534170 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16388708b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638841720>, because it is not built.
# W0731 04:22:19.534241 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638841720>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638842920>, because it is not built.
# W0731 04:22:19.534312 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638842920>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638840340>, because it is not built.
# W0731 04:22:19.534392 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638840340>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16388435b0>, because it is not built.
# W0731 04:22:19.534465 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16388435b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16388428c0>, because it is not built.
# W0731 04:22:19.534541 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a16388428c0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16388420b0>, because it is not built.
# W0731 04:22:19.534612 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a16388420b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638843730>, because it is not built.
# W0731 04:22:19.534687 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a1638843730>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638171060>, because it is not built.
# W0731 04:22:19.534759 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a1638171060>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b566b0>, because it is not built.
# W0731 04:22:19.534837 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b566b0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15e4b55a20>, because it is not built.
# W0731 04:22:19.534908 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15e4b55a20>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b55480>, because it is not built.
# W0731 04:22:19.534980 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b55480>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15e4b54b80>, because it is not built.
# W0731 04:22:19.535053 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15e4b54b80>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b57910>, because it is not built.
# W0731 04:22:19.535126 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b57910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15e4b551e0>, because it is not built.
# W0731 04:22:19.535197 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7a15e4b551e0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b57640>, because it is not built.
# W0731 04:22:19.535523 134237902726272 save_impl.py:66] Skipping full serialization of Keras layer <keras.src.layers.core.lambda_layer.Lambda object at 0x7a15e4b57640>, because it is not built.
# I0731 04:22:34.958831 134237902726272 save.py:274] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/export/saved_model/assets
# I0731 04:22:40.478094 134237902726272 builder_impl.py:804] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/export/saved_model/assets
# I0731 04:22:40.769944 134237902726272 fingerprinting_utils.py:48] Writing fingerprint to Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/export/saved_model/fingerprint.pb
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/export/pipeline.config
# I0731 04:22:41.283692 134237902726272 config_util.py:253] Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/export/pipeline.config

# %% [markdown]
# Conversion to TFJS

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.9.0-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.0/89.0 kB 2.5 MB/s eta 0:00:00
# Collecting flax<0.6.3,>=0.6.2 (from tensorflowjs)
#   Downloading flax-0.6.2-py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.9/189.9 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (6.0.0)
# Requirement already satisfied: jax>=0.3.16 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.4.13)
# Requirement already satisfied: tensorflow<3,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (2.13.0)
# Collecting tensorflow-decision-forests>=1.3.0 (from tensorflowjs)
#   Downloading tensorflow_decision_forests-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 56.3 MB/s eta 0:00:00
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (1.16.0)
# Requirement already satisfied: tensorflow-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflowjs) (0.14.0)
# Collecting packaging~=20.9 (from tensorflowjs)
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs) (1.25.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs) (3.7.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs) (1.0.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs) (0.1.5)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs) (0.1.40)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs) (13.4.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from flax<0.6.3,>=0.6.2->tensorflowjs) (4.5.0)
# Collecting PyYAML>=5.4.1 (from flax<0.6.3,>=0.6.2->tensorflowjs)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 50.9 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.16->tensorflowjs) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.16->tensorflowjs) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.16->tensorflowjs) (1.10.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging~=20.9->tensorflowjs) (2.4.7)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (1.56.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (16.0.6)
# Collecting numpy>=1.12 (from flax<0.6.3,>=0.6.2->tensorflowjs)
#   Using cached numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (67.7.2)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3,>=2.12.0->tensorflowjs) (0.32.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.3.0->tensorflowjs) (1.5.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow-decision-forests>=1.3.0->tensorflowjs) (0.41.0)
# Collecting wurlitzer (from tensorflow-decision-forests>=1.3.0->tensorflowjs)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax<0.6.3,>=0.6.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax<0.6.3,>=0.6.2->tensorflowjs) (2.14.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (2.3.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax<0.6.3,>=0.6.2->tensorflowjs) (2.8.2)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from optax->flax<0.6.3,>=0.6.2->tensorflowjs) (0.1.7)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.10/dist-packages (from optax->flax<0.6.3,>=0.6.2->tensorflowjs) (0.4.13+cuda11.cudnn86)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow-decision-forests>=1.3.0->tensorflowjs) (2022.7.1)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax<0.6.3,>=0.6.2->tensorflowjs) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax<0.6.3,>=0.6.2->tensorflowjs) (0.12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax<0.6.3,>=0.6.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow<3,>=2.12.0->tensorflowjs) (3.2.2)
# Installing collected packages: wurlitzer, PyYAML, packaging, numpy, tensorflow-decision-forests, flax, tensorflowjs
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.3.1
#     Uninstalling PyYAML-5.3.1:
#       Successfully uninstalled PyYAML-5.3.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.1
#     Uninstalling numpy-1.25.1:
#       Successfully uninstalled numpy-1.25.1
#   Attempting uninstall: flax
#     Found existing installation: flax 0.7.0
#     Uninstalling flax-0.7.0:
#       Successfully uninstalled flax-0.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.3 which is incompatible.
# statsmodels 0.13.5 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# tf-models-official 2.13.1 requires pyyaml<5.4.0,>=5.1, but you have pyyaml 6.0.1 which is incompatible.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# Successfully installed PyYAML-6.0.1 flax-0.6.2 numpy-1.24.3 packaging-20.9 tensorflow-decision-forests-1.5.0 tensorflowjs-4.9.0 wurlitzer-3.0.3

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/export/saved_model Tensorflow/workspace/models/my_ssd_mobnet_fpnlite_640_5/tfjsexport

# %%
# !{command}
# Out:
# 2023-07-31 04:22:58.642554: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-31 04:23:02.223945: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.

# %% [markdown]
# Zip and exporting model mainly for using in google colab

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}
